# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tick="WIPRO.NS"

# %%
data=yf.download(tick,start="2023-04-01",end="2024-03-31")
df=pd.DataFrame(data)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-04-03  367.950012  368.399994  365.149994  367.950012  367.166962
# 2023-04-05  369.700012  371.899994  367.200012  369.750000  368.963135
# 2023-04-06  369.000000  370.450012  365.850006  366.649994  365.869720
# 2023-04-10  368.000000  374.399994  367.600006  373.299988  372.505554
# 2023-04-11  373.500000  374.850006  368.600006  370.250000  369.462067
# ...                ...         ...         ...         ...         ...
# 2024-03-21  499.649994  505.299988  498.450012  500.450012  500.450012
# 2024-03-22  489.250000  490.750000  479.549988  487.100006  487.100006
# 2024-03-26  486.000000  490.950012  479.049988  479.850006  479.850006
# 2024-03-27  479.700012  480.950012  471.250000  472.299988  472.299988
# 2024-03-28  476.700012  483.049988  475.299988  480.100006  480.100006
#
#               Volume
# Date
# ...

# %%
df2=pd.DataFrame()

# %%
x=len(df)

# %%
df2["Close"]=0.25*(df["Close"]+df["High"]+df["Low"]+df["Open"])

# %%
df2["Open"]=0
for index in range(1,x):
    df2["Open"][index]=0.5*(df["Open"][index-1]+df["Close"][index-1])
# Out:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_22628\1653497039.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df2["Open"][index]=0.5*(df["Open"][index-1]+df["Close"][index-1])
# C:\Users\rakes\AppData\Local\Temp\ipykernel_22628\1653497039.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Open"][index]=0.5*(df["Open"][index-1]+df["Close"][index-1])
# ...

# %%
for index in range(0,x):
    df2["High"][index]=max(df2["Close"][index],df2["Open"][index])
    df2["High"][index]= max(df["High"][index],df2["High"][index])
def max(a,b):
    if(a>=b):
        return a
    else:
        return b
# Out:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_22628\2803886448.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df2["High"][index]=max(df2["Close"][index],df2["Open"][index])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 for index in range(0,x):
# ----> 2     df2["High"][index]=max(df2["Close"][index],df2["Open"][index])
#       3     df2["High"][index]= max(df["High"][index],df2["High"][index])
#       4 def max(a,b):
#
# TypeError: max() missing 1 required positional argument: 'c'

# %%
list2=[df2["Open"],df2["Close"],df["Low"]]
df2["Low"]=np.min(list2)

# %%
df2
# Out:
#                  Close        Open        High  Low
# Date
# 2023-04-03  367.362503    0.000000  545.900024  0.0
# 2023-04-05  369.637505  367.950012  545.900024  0.0
# 2023-04-06  367.987503  369.725006  545.900024  0.0
# 2023-04-10  370.824997  367.824997  545.900024  0.0
# 2023-04-11  371.800003  370.649994  545.900024  0.0
# ...                ...         ...         ...  ...
# 2024-03-21  500.962502  494.774994  545.900024  0.0
# 2024-03-22  486.662498  500.050003  545.900024  0.0
# 2024-03-26  483.962502  488.175003  545.900024  0.0
# 2024-03-27  476.050003  482.925003  545.900024  0.0
# 2024-03-28  478.787498  476.000000  545.900024  0.0
#
# [243 rows x 4 columns]
