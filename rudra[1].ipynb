# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
data=yf.download("TATASTEEL.NS",start="2018-01-01",end="2020-01-01")
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-01-01  69.787956  70.064255  68.549400  68.806641  57.710377   19249201
# 2018-01-02  68.978134  69.668869  68.144485  69.483086  58.277740   25896915
# 2018-01-03  69.740318  70.264328  69.668869  70.021378  58.729221   27654851
# 2018-01-04  70.169052  72.736679  69.740318  72.431801  60.750916   84839667
# 2018-01-05  72.789078  74.018112  72.646172  73.427414  61.585972   74902157
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-24  46.220001  46.470001  45.939999  46.299999  40.558655  112355050
# 2019-12-26  46.299999  47.200001  46.299999  46.790001  40.987892  182556030
# 2019-12-27  46.924999  47.180000  46.320000  46.950001  41.128056  111443330
# 2019-12-30  47.009998  47.630001  46.509998  47.474998  41.587952  114620740
# 2019-12-31  47.264999  47.529999  46.950001  47.205002  41.351437   96441450
#
# [489 rows x 6 columns]

# %%
# def ema(data,period,column):
#     return data[column].ewm(span=period,adjust=False).mean()
# data["12_ema"]=ema(data,12,"Close")
# data["26_ema"]=ema(data,26,"Close")
# data['macd']=data["12_ema"]-data["26_ema"]
# data["signal_line"]=ema(data,9,"macd")
# data["daily_return"]=(data["Close"]-data["Open"])/data["Open"]


# # rsi code
# def SMA(data,period):
#     return data.rolling(window=period).mean()
# data["returns"]=(data["Close"]-data["Open"])/data["Open"]
# def rsi(data,period,column):

#    avg_gain = data[column].where(data[column] > 0, 0).rolling(window=14).mean()
#    avg_loss = data[column].where(data[column] < 0, 0).rolling(window=14).mean().abs()
#    RS=avg_gain/avg_loss
#    data["RSI"]=100-(100/(1+RS))
# rsi(data,14,"returns")

# data["signal"]=0
# def signal(data):
#     for x in range(data.shape[0]-1):
#         if data["macd"].iloc[x]<data["signal_line"].iloc[x] and data["macd"].iloc[x+1]>=data["signal_line"].iloc[x+1] and data["RSI"].iloc[x+1]<=30:
#             data["signal"].iloc[x+1]=1
#         elif data["macd"].iloc[x]>data["signal_line"].iloc[x] and data["macd"].iloc[x+1]<=data["signal_line"].iloc[x+1] and data["RSI"].iloc[x+1]>=60:
#             data["signal"].iloc[x+1]=-1

# signal(data)


# bollinger band
def bb(data,period,column):
    std=data[column].rolling(window=20).std()
    data["middle"]=data[column].rolling(window=20).mean()
    data["upper"]=data["middle"]+2*std
    data["lower"]=data["middle"]-2*std
bb(data,20,"Close")
data["signal"]=0
def sig(data,column):
    for x in range(data.shape[0]-1):
        if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
            data["signal"][x+1]=-1
        elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
            data["signal"][x+1]=1

sig(data,"Close")
# Out:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data["signal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data["Close"][x]<data['upper'][x] and data["Close"][x+1]>=data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1816027631.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif data["Close"][x]>data["lower"][x]  and data["Close"][x+1]<=data["lower"][x+1]:

# %%
curr=0
capital=10000000
portfolio=[]
entry=0
no=0
data["portfol"]=0
for x in range(len(data)):
    if curr==0 and data["signal"][x]==1:
        curr=1
        entry=data["Close"][x]
        no=capital//data["Close"][x]
        capital=capital-no*entry
        # data["portfol"][x]=no*entry
        portfolio.append(no*entry)
    elif curr==0 and data["signal"][x]==-1:
        curr=-1
        no=capital//data["Close"][x]
        entry=data["Close"][x]

        # data["portfol"][x]=no*data["Close"][x]
        portfolio.append(no*data["Close"][x])
    elif curr==1 and data["Close"][x]<entry*(1-.01):
        curr=0
        
        # data["portfol"][x]=no*entry*(1-.001)
        portfolio.append(no*entry*(1-.01))
        capital=capital+no*entry*(1-.01)
    elif curr==1 and data["Close"][x]>entry*(1+.05) :
        curr=0
        # data["portfol"][x]=no*entry*(1+.01)
        portfolio.append(no*entry*(1+.05))
        capital=capital+no*entry*(1+.05)
    elif curr==1 and data["signal"][x]==-1:
        curr=0
        # data["portfol"][x]=no*(data["Close"][x])
        portfolio.append(no*data["Close"][x])
        capital=capital+no*(data["Close"][x])
    elif curr==-1 and data["Close"][x]>entry*(1+.01):
        curr=0
        # data["portfol"][x]=no*entry*(1+.001)
        portfolio.append(no*entry*(1+.01))
        capital=capital+no*entry-no*entry*(1+.01)
    elif curr==-1 and data["Close"][x]<entry*(1-.05) :
        curr=0
        # data["portfol"][x]=no*entry*(1-.01)
        portfolio.append(no*entry*(1-.05))
        capital=capital+no*entry-no*entry*(1-.05)
    elif curr==-1 and data["signal"][x]==1:
        curr=0
        # data["portfol"][x]=no*data["Close"][x]
        portfolio.append(no*data["Close"][x])
        capital=capital+no*entry-no*data["Close"][x]     
    elif curr==-1 or curr==1:
        portfolio.append(no*data["Close"][x])
if curr==1 :

    capital=capital+data["Close"][len(data)-1]      
    
elif curr==-1:
    capital=capital+no*entry-no*data["Close"][len(data)-1]
capital
# Out:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if curr==0 and data["signal"][x]==1:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==0 and data["signal"][x]==-1:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   entry=data["Close"][x]
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   no=capital//data["Close"][x]
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==1 and data["Close"][x]<entry*(1-.01):
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==1 and data["Close"][x]>entry*(1+.05) :
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==1 and data["signal"][x]==-1:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:54: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   portfolio.append(no*data["Close"][x])
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   no=capital//data["Close"][x]
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   entry=data["Close"][x]
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   portfolio.append(no*data["Close"][x])
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==-1 and data["Close"][x]>entry*(1+.01):
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==-1 and data["Close"][x]<entry*(1-.05) :
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4270537773.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==-1 and data["signal"][x]==1:
# 9758120.309640918

# %%
portfolio
# Out:
# [9999965.462997437,
#  9899965.808367463,
#  9899975.575515747,
#  10163485.709381104,
#  10260567.866134644,
#  10125142.069793701,
#  9981557.575515747,
#  9800975.819760589,
#  9800999.9829216,
#  10108692.969944,
#  9925440.814888,
#  9902428.0560112,
#  9702989.983092384,
#  9702979.707389832,
#  9457265.41336441,
#  9463505.916194916,
#  9322317.96163559,
#  9217830.72202034,
#  10188087.588684082,
#  10111589.25,
#  9933364.661315918,
#  9678683.209249878,
#  10697526.631576538,
#  10858964.81954956,
#  11232402.963155365,
#  11232415.834960938,
#  11515795.33203125,
#  11120091.676611328,
#  11120090.317649841,
#  10976599.410541534,
#  10981169.464458466,
#  10840420.310783386,
#  10865096.788974762,
#  10972943.506866455,
#  11231291.220826339,
#  11008875.0,
#  11045807.942199707,
#  10977623.826599121,
#  11028761.91329956,
#  10898786.25,
#  10898773.55732727,
#  10789785.821753997,
#  10789807.146865845,
#  10681909.075397186,
#  10681914.968170166,
#  10592092.115882874,
#  10687902.904510498,
#  10592092.115882874,
#  10788734.117851868,
#  10575097.226295471,
#  10469346.254032517,
#  10469342.468261719,
#  10478289.873046875,
#  10364649.043579102,
#  10364628.866729736,
#  10789153.057250977,
#  10488240.0,
#  10260982.57806244,
#  10261003.40102005,
#  10158393.36700985,
#  10158384.568805695,
#  10056800.723117638,
#  10056780.797981262,
#  10000079.003364563,
#  9808067.448654175,
#  10157348.605961075,
#  9956242.824905396,
#  9890516.696006775,
#  10055805.25315445,
#  9856640.673751831,
#  9881229.182624817,
#  9899402.836875916,
#  9955207.080489349]

# %%
# calculation of max drawdown
def max_drawdown(column):
    # max price till date =pmax
    # max drawdown=mdd
    # maximise "d" to calculate the max drawdown  WHERE  [d=(1-(price_curr)/pmax)]
    pmax=0
    mdd=0
    d=0
    for x in range(len(column)):
        if column[x]>pmax:
            pmax=column[x]
        d=1-((column[x])/pmax)
        if d>mdd:
            mdd=d
    return mdd    
100*max_drawdown(portfolio)
# Out:
# 14.829439340824512

# %%
data["returns"]=(data["Close"]-data["Open"])/data["Open"]
# sharpe
def sharpe(data,column):
    std=data[column].std()
    sharpe=(np.sqrt(252)*data[column].mean()-0)/std
    return sharpe
sharpe_ratio=sharpe(data,"returns")
print("sharpe_ratio=",sharpe_ratio)
# Out:
# sharpe_ratio= -1.3205793135800465

# %%
def heikenA(df):
    df['Hclose'] = (df['Open'] + df['High'] + df['Low'] + df['Close'])/4

    df['Hopen'] = 0
    for i in range(len(df)):
        if i == 0:
            df['Hopen'].iloc[i] = (df['Open'].iloc[i] + df['Close'].iloc[i])/2
        else:
            df['Hopen'].iloc[i] = (df['Hopen'].iloc[i-1] + df['Hclose'].iloc[i-1])/2

    df['Hhigh'] = df[['High', 'Hopen', 'Hclose']].max(axis=1)
    df['Hlow'] = df[['Low', 'Hopen', 'Hclose']].min(axis=1)
heikenA(data)    
new_data=data[["Hopen","Hhigh","Hlow","Hclose"]].copy()
# Out:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\3389637120.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hopen'].iloc[i] = (df['Open'].iloc[i] + df['Close'].iloc[i])/2
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\3389637120.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '69.29729843139648' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df['Hopen'].iloc[i] = (df['Open'].iloc[i] + df['Close'].iloc[i])/2

# %%
new_data
# Out:
#                 Hopen      Hhigh       Hlow     Hclose
# Date
# 2018-01-01  69.297298  70.064255  68.549400  69.302063
# 2018-01-02  69.299681  69.668869  68.144485  69.068644
# 2018-01-03  69.184162  70.264328  69.184162  69.923723
# 2018-01-04  69.553943  72.736679  69.553943  71.269463
# 2018-01-05  70.411703  74.018112  70.411703  73.220194
# ...               ...        ...        ...        ...
# 2019-12-24  45.419153  46.470001  45.419153  46.232500
# 2019-12-26  45.825827  47.200001  45.825827  46.647500
# 2019-12-27  46.236663  47.180000  46.236663  46.843750
# 2019-12-30  46.540207  47.630001  46.509998  47.156249
# 2019-12-31  46.848228  47.529999  46.848228  47.237500
#
# [489 rows x 4 columns]

# %%
def bb(data,period,column):
    std=data[column].rolling(window=20).std()
    data["middle"]=data[column].rolling(window=20).mean()
    data["upper"]=data["middle"]+2*std
    data["lower"]=data["middle"]-2*std
bb(new_data,20,"Hclose")
new_data["Hsignal"]=0
def sig(new_data,column):
    for x in range(new_data.shape[0]-1):
        if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
            new_data["Hsignal"][x+1]=-1
        elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
            new_data["Hsignal"][x+1]=1

sig(new_data,"Hclose")
# Out:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:11: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new_data["Hsignal"][x+1]=-1
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if new_data["Hclose"][x]<new_data['upper'][x] and new_data["Hclose"][x+1]>=new_data['upper'][x+1]:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\4105338082.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif new_data["Hclose"][x]>new_data["lower"][x]  and new_data["Hclose"][x+1]<=new_data["lower"][x+1]:

# %%
new_data["Hreturns"]=(new_data["Hclose"]-new_data["Hopen"])/new_data["Hopen"]
new_data
# Out:
#                 Hopen      Hhigh       Hlow     Hclose     middle      upper  \
# Date
# 2018-01-01  69.297298  70.064255  68.549400  69.302063        NaN        NaN
# 2018-01-02  69.299681  69.668869  68.144485  69.068644        NaN        NaN
# 2018-01-03  69.184162  70.264328  69.184162  69.923723        NaN        NaN
# 2018-01-04  69.553943  72.736679  69.553943  71.269463        NaN        NaN
# 2018-01-05  70.411703  74.018112  70.411703  73.220194        NaN        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-24  45.419153  46.470001  45.419153  46.232500  42.478562  46.461169
# 2019-12-26  45.825827  47.200001  45.825827  46.647500  42.694875  47.090086
# 2019-12-27  46.236663  47.180000  46.236663  46.843750  42.898625  47.669973
# 2019-12-30  46.540207  47.630001  46.509998  47.156249  43.124500  48.258019
# 2019-12-31  46.848228  47.529999  46.848228  47.237500  43.371687  48.804171
#
#                 lower  Hsignal  Hreturns
# Date
# 2018-01-01        NaN        0  0.000069
# 2018-01-02        NaN        0 -0.003334
# 2018-01-03        NaN        0  0.010690
# 2018-01-04        NaN        0  0.024665
# 2018-01-05        NaN        0  0.039887
# ...               ...      ...       ...
# 2019-12-24  38.495956        0  0.017908
# 2019-12-26  38.299663        0  0.017930
# 2019-12-27  38.127277        0  0.013130
# 2019-12-30  37.990981        0  0.013237
# 2019-12-31  37.939204        0  0.008309
#
# [489 rows x 9 columns]

# %%
curr=0
capital=10000000
Hportfolio=[]
entry=0
no=0

for x in range(len(new_data)):
    if curr==0 and new_data["Hsignal"][x]==1:
        curr=1
        entry=new_data["Hclose"][x]
        no=capital//new_data["Hclose"][x]
        capital=capital-no*entry
        # new_data["Hportfol"][x]=no*entry
        Hportfolio.append(no*entry)
    elif curr==0 and new_data["Hsignal"][x]==-1:
        curr=-1
        no=capital//new_data["Hclose"][x]
        entry=new_data["Hclose"][x]

        # new_data["Hportfol"][x]=no*new_data["Hsignal"][x]
        Hportfolio.append(no*new_data["Hclose"][x])
    elif curr==1 and new_data["Hclose"][x]<entry*(1-.01):
        curr=0
        
        # new_data["Hportfol"][x]=no*entry*(1-.001)
        Hportfolio.append(no*entry*(1-.01))
        capital=capital+no*entry*(1-.01)
    elif curr==1 and new_data["Hclose"][x]>entry*(1+.05) :
        curr=0
        # new_data["Hportfol"][x]=no*entry*(1+.01)
        Hportfolio.append(no*entry*(1+.05))
        capital=capital+no*entry*(1+.05)
    elif curr==1 and new_data["Hsignal"][x]==-1:
        curr=0
        # new_data["Hportfol"][x]=no*(new_data["Hsignal"][x])
        Hportfolio.append(no*new_data["Hclose"][x])
        capital=capital+no*(new_data["Hclose"][x])
    elif curr==-1 and new_data["Hclose"][x]>entry*(1+.01):
        curr=0
        # new_data["Hportfol"][x]=no*entry*(1+.001)
        Hportfolio.append(no*entry*(1+.01))
        capital=capital+no*entry-no*entry*(1+.01)
    elif curr==-1 and new_data["Hclose"][x]<entry*(1-.05) :
        curr=0
        # new_data["Hportfol"][x]=no*entry*(1-.01)
        Hportfolio.append(no*entry*(1-.05))
        capital=capital+no*entry-no*entry*(1-.05)
    elif curr==-1 and new_data["Hsignal"][x]==1:
        curr=0
        # new_data["Hportfol"][x]=no*new_data["Hsignal"][x]
        Hportfolio.append(no*new_data["Hclose"][x])
        capital=capital+no*entry-no*new_data["Hclose"][x]     
    elif curr==-1 or curr==1:
        Hportfolio.append(no*new_data["Hclose"][x])
if curr==1 :

    capital=capital+new_data["Hclose"][len(new_data)-1]      
    
elif curr==-1:
    capital=capital+no*entry-no*new_data["Hclose"][len(new_data)-1]
capital
# Out:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if curr==0 and new_data["Hsignal"][x]==1:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==0 and new_data["Hsignal"][x]==-1:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   entry=new_data["Hclose"][x]
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   no=capital//new_data["Hclose"][x]
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==1 and new_data["Hclose"][x]<entry*(1-.01):
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==1 and new_data["Hclose"][x]>entry*(1+.05) :
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==1 and new_data["Hsignal"][x]==-1:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:54: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Hportfolio.append(no*new_data["Hclose"][x])
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   no=capital//new_data["Hclose"][x]
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   entry=new_data["Hclose"][x]
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Hportfolio.append(no*new_data["Hclose"][x])
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==-1 and new_data["Hclose"][x]>entry*(1+.01):
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==-1 and new_data["Hclose"][x]<entry*(1-.05) :
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\2858562424.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif curr==-1 and new_data["Hsignal"][x]==1:
# 12224121.750510562

# %%
Hportfolio
# Out:
# [9999995.085897446,
#  9899995.13503847,
#  9899990.900707245,
#  9831103.516426086,
#  9957713.065704346,
#  9800990.991700172,
#  9800991.99055481,
#  9877943.807556152,
#  9784968.467926025,
#  9548573.477371216,
#  9310942.391027069,
#  10291029.713413239,
#  10188119.416279105,
#  10188136.817481995,
#  10086255.449307175,
#  10086249.962425232,
#  9853271.950149536,
#  9753424.430894852,
#  10034182.087612152,
#  10031119.243955612,
#  10064810.368394852,
#  10157919.818544388,
#  10156490.512275696,
#  9999061.81268692,
#  9776497.56231308,
#  9907381.668806076,
#  10008862.881231308,
#  9720345.99981308,
#  9581937.46430397,
#  10590568.798559189,
#  10733304.590194702,
#  10954497.604322433,
#  10517074.041635513,
#  10748665.444049835,
#  10843192.263753891,
#  10858789.125,
#  10701874.319423676,
#  10484663.110573597,
#  10484664.091966629,
#  10348613.516516685,
#  10202249.577946663,
#  10171528.636879921,
#  10007609.73134327,
#  9960430.887368297,
#  11008890.413360596,
#  10898801.509226989,
#  10898805.90959549,
#  10861873.143134117,
#  11000370.96399784,
#  10935178.969016075,
#  10859914.595422745,
#  10789817.850499535,
#  10789779.48969841,
#  11098395.98900795,
#  11329268.46418333,
#  11329295.2150774,
#  11305175.934553146,
#  11414904.03087616,
#  11276551.565446854,
#  11442588.167228173,
#  11216003.733997345,
#  11103843.69665737,
#  11103831.575826645,
#  11024297.242944717,
#  11046827.43514824,
#  11022668.62421608,
#  11062028.428876877,
#  10812839.615592957,
#  10579123.301525116,
#  10548639.997035312,
#  11659023.57720375,
#  11591049.086380005,
#  11632588.849277496,
#  11542433.341431713,
#  11542449.939687729,
#  11427025.440290852,
#  11427010.34779358,
#  11302376.945680618,
#  10990793.008180618,
#  11205313.83970642,
#  11059530.01350975,
#  10855659.8304039,
#  11998378.014579773,
#  11968867.78280449,
#  12034698.35313034,
#  12243993.533340454,
#  12587673.411985397,
#  12598296.915308762,
#  12598291.089580536,
#  12724274.000476342,
#  12472305.758972168,
#  12476877.974281311,
#  12298576.691986084,
#  12227713.749401093,
#  12197234.54246521,
#  12151135.683013916,
#  12194186.88337326,
#  12009789.992225647,
#  12039888.132774353,
#  12306196.275718689,
#  12424682.924640656,
#  12233428.001197815,
#  11936260.166267395,
#  11977406.325359344,
#  12562980.375,
#  12597028.816561889,
#  12347565.359635353,
#  12341652.504572868,
#  12471041.013231706]

# %%
# sharpe
def sharpe(new_data,column):
    std=new_data[column].std()
    sharpe=(np.sqrt(252)*new_data[column].mean()-0)/std
    return sharpe
sharpe_ratio=sharpe(new_data,"Hreturns")
print("sharpe_ratio=",sharpe_ratio)
# Out:
# sharpe_ratio= -1.0472719588454578

# %%
# calculation of max drawdown
def max_drawdown(column):
    # max price till date =pmax
    # max drawdown=mdd
    # maximise "d" to calculate the max drawdown  WHERE  [d=(1-(price_curr)/pmax)]
    pmax=0
    mdd=0
    d=0
    for x in range(len(column)):
        if column[x]>pmax:
            pmax=column[x]
        d=1-((column[x])/pmax)
        if d>mdd:
            mdd=d
    return mdd    
100*max_drawdown(Hportfolio)
# Out:
# 9.074507593683679

# %%
tickers=["TATASTEEL.NS","^NSEI"]
data=pd.DataFrame()
for t in tickers:
    data[t]=yf.download(t,start="2018-01-01",end="2020-01-01")["Close"]
returns=np.log(data/data.shift(1))
market_var=returns["^NSEI"].var()
cov=returns.cov()
cov
beta=cov.iloc[1,0]/market_var
beta
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 1.485524738679312

# %%
market_initial_price=4546.20  #of Nifty 50 Index
market_final_price=22530.70
years=16
cagr=((market_final_price/market_initial_price)**(1/16)-1)*100
cagr
# Out:
# 10.521147199334347

# %%
cov
# Out:
#               TATASTEEL.NS     ^NSEI
# TATASTEEL.NS      0.000503  0.000105
# ^NSEI             0.000105  0.000071

# %%
tickers=["TATASTEEL.NS","^NSEI"]
data=pd.DataFrame()
for t in tickers:
    data[t]=yf.download(t,start="2018-01-01",end="2020-01-01")["Close"]
data["TATASTEEL.NS"]=new_data["Hclose"]
returns=np.log(data/data.shift(1))
market_var=returns["^NSEI"].var()
cov=returns.cov()
cov
beta2=cov.iloc[1,0]/market_var
beta2
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 0.954358156439643

# %%
data["trade_returns"]=0
for i in range(len(portfolio)):
    data["trade_returns"].iloc[i]=(portfolio[i]-portfolio[i-1])/portfolio[i-1]
alpha=data["trade_returns"].sum()*100-beta*cagr
alpha
# Out:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1192217804.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["trade_returns"].iloc[i]=(portfolio[i]-portfolio[i-1])/portfolio[i-1]
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\1192217804.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.004495977044596826' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data["trade_returns"].iloc[i]=(portfolio[i]-portfolio[i-1])/portfolio[i-1]
# -13.719498866895242

# %%
new_data["trade_returns"]=0
for i in range(len(Hportfolio)):
    new_data["trade_returns"].iloc[i]=(Hportfolio[i]-Hportfolio[i-1])/Hportfolio[i-1]
alpha2=new_data["trade_returns"].sum()*100-beta2*cagr
alpha2
# Out:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\3113121385.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["trade_returns"].iloc[i]=(Hportfolio[i]-Hportfolio[i-1])/Hportfolio[i-1]
# C:\Users\rakes\AppData\Local\Temp\ipykernel_36940\3113121385.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.19814271516808374' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   new_data["trade_returns"].iloc[i]=(Hportfolio[i]-Hportfolio[i-1])/Hportfolio[i-1]
# -4.0887725368198815
